# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 738

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ostersund
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | nuuk
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | mergui
# City not found. Skipping
# Processing Record 8 of Set 1 | inderborskiy
# City not found. Skipping
# Processing Record 9 of Set 1 | srednekolymsk
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | gat
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | port hardy
# Processing Record 14 of Set 1 | domoni
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | bambanglipuro
# Processing Record 18 of Set 1 | khvastovichi
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | hukuntsi
# Processing Record 23 of Set 1 | vardo
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | tambacounda
# Processing Record 27 of Set 1 | altrincham
# Processing Record 28 of Set 1 | uyskoye
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | maneromango
# Processing Record 32 of Set 1 | jumla
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | chikoy
# City not found. Skipping
# Processing Record 35 of Set 1 | batagay-alyta
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | sitka
# Processing Record 38 of Set 1 | santa isabel do rio negro
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 41 of Set 1 | uruzgan
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | khandyga
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | talnakh
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 48 of Set 1 | bilibino
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | warqla
# City not found. Skipping
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | acarau
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | omboue
# Processing Record 12 of Set 2 | constitucion
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | ostrovnoy
# Processing Record 15 of Set 2 | tsihombe
# City not found. Skipping
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | nantucket
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | samusu
# City not found. Skipping
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | surt
# Processing Record 23 of Set 2 | gayeri
# Processing Record 24 of Set 2 | praia da vitoria
# Processing Record 25 of Set 2 | narsaq
# Processing Record 26 of Set 2 | alice springs
# Processing Record 27 of Set 2 | clyde river
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | vostok
# Processing Record 32 of Set 2 | les cayes
# Processing Record 33 of Set 2 | alvand
# Processing Record 34 of Set 2 | kahului
# Processing Record 35 of Set 2 | puerto baquerizo moreno
# Processing Record 36 of Set 2 | kruisfontein
# Processing Record 37 of Set 2 | guerrero negro
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | tezu
# Processing Record 41 of Set 2 | marcona
# City not found. Skipping
# Processing Record 42 of Set 2 | carutapera
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | mayo
# Processing Record 45 of Set 2 | halalo
# City not found. Skipping
# Processing Record 46 of Set 2 | itaituba
# Processing Record 47 of Set 2 | korla
# Processing Record 48 of Set 2 | prudnik
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | alpena
# Processing Record 1 of Set 3 | mishelevka
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | panaba
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | salym
# Processing Record 6 of Set 3 | vanimo
# Processing Record 7 of Set 3 | agadez
# Processing Record 8 of Set 3 | itarema
# Processing Record 9 of Set 3 | novo selo
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | marawi
# Processing Record 13 of Set 3 | namatanai
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | dien bien
# City not found. Skipping
# Processing Record 16 of Set 3 | doka
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | kingsport
# Processing Record 20 of Set 3 | akniste
# Processing Record 21 of Set 3 | novomikhaylovskiy
# Processing Record 22 of Set 3 | wenling
# Processing Record 23 of Set 3 | eureka
# Processing Record 24 of Set 3 | pisco
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | shache
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | te anau
# Processing Record 29 of Set 3 | tabiauea
# City not found. Skipping
# Processing Record 30 of Set 3 | talara
# Processing Record 31 of Set 3 | lahaina
# Processing Record 32 of Set 3 | rawson
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping
# Processing Record 34 of Set 3 | tuatapere
# Processing Record 35 of Set 3 | puerto escondido
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | nouadhibou
# Processing Record 38 of Set 3 | yar-sale
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | atocha
# Processing Record 42 of Set 3 | solovetskiy
# City not found. Skipping
# Processing Record 43 of Set 3 | abu samrah
# Processing Record 44 of Set 3 | qaqortoq
# Processing Record 45 of Set 3 | maumere
# Processing Record 46 of Set 3 | jitauna
# Processing Record 47 of Set 3 | ruatoria
# City not found. Skipping
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | port blair
# Processing Record 50 of Set 3 | la ronge
# Processing Record 1 of Set 4 | vanersborg
# Processing Record 2 of Set 4 | san quintin
# Processing Record 3 of Set 4 | ust-maya
# Processing Record 4 of Set 4 | broome
# Processing Record 5 of Set 4 | agara
# Processing Record 6 of Set 4 | rantauprapat
# Processing Record 7 of Set 4 | hambantota
# Processing Record 8 of Set 4 | kerema
# Processing Record 9 of Set 4 | isangel
# Processing Record 10 of Set 4 | albox
# Processing Record 11 of Set 4 | smithers
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | itinga
# Processing Record 14 of Set 4 | porto novo
# Processing Record 15 of Set 4 | luoyang
# Processing Record 16 of Set 4 | dinghai
# Processing Record 17 of Set 4 | maarianhamina
# Processing Record 18 of Set 4 | mys shmidta
# City not found. Skipping
# Processing Record 19 of Set 4 | kavaratti
# Processing Record 20 of Set 4 | yining
# Processing Record 21 of Set 4 | mehamn
# Processing Record 22 of Set 4 | sentyabrskiy
# City not found. Skipping
# Processing Record 23 of Set 4 | karaul
# City not found. Skipping
# Processing Record 24 of Set 4 | bur gabo
# City not found. Skipping
# Processing Record 25 of Set 4 | fallon
# Processing Record 26 of Set 4 | bolungarvik
# City not found. Skipping
# Processing Record 27 of Set 4 | payakumbuh
# Processing Record 28 of Set 4 | kodinsk
# Processing Record 29 of Set 4 | onega
# Processing Record 30 of Set 4 | harper
# Processing Record 31 of Set 4 | geraldton
# Processing Record 32 of Set 4 | kieta
# Processing Record 33 of Set 4 | san patricio
# Processing Record 34 of Set 4 | ahipara
# Processing Record 35 of Set 4 | saldanha
# Processing Record 36 of Set 4 | sorvag
# City not found. Skipping
# Processing Record 37 of Set 4 | nenagh
# Processing Record 38 of Set 4 | novaci
# Processing Record 39 of Set 4 | sisimiut
# Processing Record 40 of Set 4 | saint anthony
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | vila do maio
# Processing Record 43 of Set 4 | hofn
# Processing Record 44 of Set 4 | iseyin
# Processing Record 45 of Set 4 | lima
# Processing Record 46 of Set 4 | zhanakorgan
# Processing Record 47 of Set 4 | baiyin
# Processing Record 48 of Set 4 | zhangye
# Processing Record 49 of Set 4 | new norfolk
# Processing Record 50 of Set 4 | arica
# Processing Record 1 of Set 5 | marsa matruh
# Processing Record 2 of Set 5 | cayenne
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping
# Processing Record 4 of Set 5 | wewak
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | laguna
# Processing Record 7 of Set 5 | hasaki
# Processing Record 8 of Set 5 | gorom-gorom
# Processing Record 9 of Set 5 | kavieng
# Processing Record 10 of Set 5 | pangnirtung
# Processing Record 11 of Set 5 | vao
# Processing Record 12 of Set 5 | maneadero
# Processing Record 13 of Set 5 | buluang
# Processing Record 14 of Set 5 | klaksvik
# Processing Record 15 of Set 5 | zhuhai
# Processing Record 16 of Set 5 | tommot
# Processing Record 17 of Set 5 | saint-georges
# Processing Record 18 of Set 5 | kloulklubed
# Processing Record 19 of Set 5 | puerto del rosario
# Processing Record 20 of Set 5 | mahajanga
# Processing Record 21 of Set 5 | hamilton
# Processing Record 22 of Set 5 | esperance
# Processing Record 23 of Set 5 | catuday
# Processing Record 24 of Set 5 | okhotsk
# Processing Record 25 of Set 5 | krasnoznamensk
# Processing Record 26 of Set 5 | carnarvon
# Processing Record 27 of Set 5 | halifax
# Processing Record 28 of Set 5 | havre-saint-pierre
# Processing Record 29 of Set 5 | manacapuru
# Processing Record 30 of Set 5 | baturaja
# Processing Record 31 of Set 5 | phayao
# Processing Record 32 of Set 5 | saint-joseph
# Processing Record 33 of Set 5 | obihiro
# Processing Record 34 of Set 5 | kushima
# Processing Record 35 of Set 5 | alyangula
# Processing Record 36 of Set 5 | pulgaon
# Processing Record 37 of Set 5 | mapiripan
# Processing Record 38 of Set 5 | nalut
# Processing Record 39 of Set 5 | tura
# Processing Record 40 of Set 5 | buta
# Processing Record 41 of Set 5 | lang son
# Processing Record 42 of Set 5 | amderma
# City not found. Skipping
# Processing Record 43 of Set 5 | sambava
# Processing Record 44 of Set 5 | poya
# Processing Record 45 of Set 5 | port lincoln
# Processing Record 46 of Set 5 | beloha
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | viligili
# City not found. Skipping
# Processing Record 49 of Set 5 | dibaya
# City not found. Skipping
# Processing Record 50 of Set 5 | vacaville
# Processing Record 1 of Set 6 | airai
# Processing Record 2 of Set 6 | sabzevar
# Processing Record 3 of Set 6 | victoria point
# Processing Record 4 of Set 6 | kundiawa
# Processing Record 5 of Set 6 | dicamay
# Processing Record 6 of Set 6 | japura
# Processing Record 7 of Set 6 | adrar
# Processing Record 8 of Set 6 | villers-les-nancy
# Processing Record 9 of Set 6 | dingle
# Processing Record 10 of Set 6 | kaeo
# Processing Record 11 of Set 6 | qaanaaq
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | fengzhen
# Processing Record 14 of Set 6 | baracoa
# Processing Record 15 of Set 6 | abadiania
# Processing Record 16 of Set 6 | saint george
# Processing Record 17 of Set 6 | girisu de cris
# Processing Record 18 of Set 6 | tautira
# Processing Record 19 of Set 6 | gumdag
# Processing Record 20 of Set 6 | chapada dos guimaraes
# Processing Record 21 of Set 6 | mayumba
# Processing Record 22 of Set 6 | san andres
# Processing Record 23 of Set 6 | sorong
# Processing Record 24 of Set 6 | comodoro rivadavia
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | mersin
# Processing Record 27 of Set 6 | ovalle
# Processing Record 28 of Set 6 | kunming
# Processing Record 29 of Set 6 | yendi
# Processing Record 30 of Set 6 | juneau
# Processing Record 31 of Set 6 | madang
# Processing Record 32 of Set 6 | san policarpo
# Processing Record 33 of Set 6 | pontypool
# Processing Record 34 of Set 6 | ischia
# Processing Record 35 of Set 6 | bubaque
# Processing Record 36 of Set 6 | lerum
# Processing Record 37 of Set 6 | jiangyou
# Processing Record 38 of Set 6 | belogorsk
# Processing Record 39 of Set 6 | zhigansk
# Processing Record 40 of Set 6 | leh
# Processing Record 41 of Set 6 | ponta do sol
# Processing Record 42 of Set 6 | asau
# Processing Record 43 of Set 6 | lyuban
# Processing Record 44 of Set 6 | lukovetskiy
# Processing Record 45 of Set 6 | bolshaya rechka
# Processing Record 46 of Set 6 | sangar
# Processing Record 47 of Set 6 | bhainsdehi
# Processing Record 48 of Set 6 | milverton
# Processing Record 49 of Set 6 | ugoofaaru
# Processing Record 50 of Set 6 | coahuayana
# Processing Record 1 of Set 7 | conde
# Processing Record 2 of Set 7 | roald
# Processing Record 3 of Set 7 | norman wells
# Processing Record 4 of Set 7 | coos bay
# Processing Record 5 of Set 7 | zhezkazgan
# Processing Record 6 of Set 7 | mitzic
# Processing Record 7 of Set 7 | provideniya
# Processing Record 8 of Set 7 | grand gaube
# Processing Record 9 of Set 7 | nabire
# Processing Record 10 of Set 7 | sulangan
# Processing Record 11 of Set 7 | lorengau
# Processing Record 12 of Set 7 | tonantins
# Processing Record 13 of Set 7 | namibe
# Processing Record 14 of Set 7 | nanortalik
# Processing Record 15 of Set 7 | bethel
# Processing Record 16 of Set 7 | kuche
# City not found. Skipping
# Processing Record 17 of Set 7 | batesville
# Processing Record 18 of Set 7 | lata
# Processing Record 19 of Set 7 | dalton
# Processing Record 20 of Set 7 | yaring
# Processing Record 21 of Set 7 | luanda
# Processing Record 22 of Set 7 | bull savanna
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | viedma
# Processing Record 25 of Set 7 | la baule-escoublac
# Processing Record 26 of Set 7 | iquitos
# Processing Record 27 of Set 7 | akdepe
# Processing Record 28 of Set 7 | ancud
# Processing Record 29 of Set 7 | mar del plata
# Processing Record 30 of Set 7 | san angelo
# Processing Record 31 of Set 7 | caravelas
# Processing Record 32 of Set 7 | katsuura
# Processing Record 33 of Set 7 | chase
# Processing Record 34 of Set 7 | kazerun
# Processing Record 35 of Set 7 | cherskiy
# Processing Record 36 of Set 7 | barawe
# City not found. Skipping
# Processing Record 37 of Set 7 | balkanabat
# Processing Record 38 of Set 7 | veraval
# Processing Record 39 of Set 7 | mitsamiouli
# Processing Record 40 of Set 7 | otradnoye
# Processing Record 41 of Set 7 | belmonte
# Processing Record 42 of Set 7 | raxaul
# Processing Record 43 of Set 7 | leningradskiy
# Processing Record 44 of Set 7 | mongo
# Processing Record 45 of Set 7 | oktyabrskoye
# Processing Record 46 of Set 7 | lodja
# Processing Record 47 of Set 7 | saint-pierre
# Processing Record 48 of Set 7 | grindavik
# Processing Record 49 of Set 7 | padang
# Processing Record 50 of Set 7 | mount gambier
# Processing Record 1 of Set 8 | husavik
# Processing Record 2 of Set 8 | kugulta
# Processing Record 3 of Set 8 | izhma
# Processing Record 4 of Set 8 | winslow
# Processing Record 5 of Set 8 | porteirinha
# Processing Record 6 of Set 8 | grand river south east
# City not found. Skipping
# Processing Record 7 of Set 8 | ibtin
# Processing Record 8 of Set 8 | ercis
# Processing Record 9 of Set 8 | egvekinot
# Processing Record 10 of Set 8 | mokhsogollokh
# Processing Record 11 of Set 8 | awjilah
# Processing Record 12 of Set 8 | roma
# Processing Record 13 of Set 8 | codrington
# Processing Record 14 of Set 8 | samarai
# Processing Record 15 of Set 8 | coihaique
# Processing Record 16 of Set 8 | celendin
# Processing Record 17 of Set 8 | porto santo
# Processing Record 18 of Set 8 | waipawa
# Processing Record 19 of Set 8 | malakisi
# City not found. Skipping
# Processing Record 20 of Set 8 | batemans bay
# Processing Record 21 of Set 8 | goya
# Processing Record 22 of Set 8 | north bend
# Processing Record 23 of Set 8 | adre
# Processing Record 24 of Set 8 | fort nelson
# Processing Record 25 of Set 8 | dongsheng
# Processing Record 26 of Set 8 | wattegama
# Processing Record 27 of Set 8 | chumikan
# Processing Record 28 of Set 8 | azimur
# City not found. Skipping
# Processing Record 29 of Set 8 | nautla
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | ukiah
# Processing Record 32 of Set 8 | anadyr
# Processing Record 33 of Set 8 | mount isa
# Processing Record 34 of Set 8 | genhe
# Processing Record 35 of Set 8 | pangai
# Processing Record 36 of Set 8 | jieshi
# Processing Record 37 of Set 8 | saint-cyr-sur-loire
# Processing Record 38 of Set 8 | port keats
# Processing Record 39 of Set 8 | tongliao
# Processing Record 40 of Set 8 | windhoek
# Processing Record 41 of Set 8 | san lawrenz
# Processing Record 42 of Set 8 | pevek
# Processing Record 43 of Set 8 | tonstad
# Processing Record 44 of Set 8 | nemuro
# Processing Record 45 of Set 8 | puerto colombia
# Processing Record 46 of Set 8 | svetlaya
# Processing Record 47 of Set 8 | vilyuysk
# Processing Record 48 of Set 8 | touros
# Processing Record 49 of Set 8 | labutta
# City not found. Skipping
# Processing Record 50 of Set 8 | ranong
# Processing Record 1 of Set 9 | rupert
# Processing Record 2 of Set 9 | atambua
# Processing Record 3 of Set 9 | machico
# Processing Record 4 of Set 9 | avila
# Processing Record 5 of Set 9 | antofagasta
# Processing Record 6 of Set 9 | santa maria
# Processing Record 7 of Set 9 | lavrentiya
# Processing Record 8 of Set 9 | lishui
# Processing Record 9 of Set 9 | waterloo
# Processing Record 10 of Set 9 | eskasem
# City not found. Skipping
# Processing Record 11 of Set 9 | najran
# Processing Record 12 of Set 9 | bongandanga
# Processing Record 13 of Set 9 | wanning
# Processing Record 14 of Set 9 | paamiut
# Processing Record 15 of Set 9 | bondo
# Processing Record 16 of Set 9 | yeniseysk
# Processing Record 17 of Set 9 | diffa
# Processing Record 18 of Set 9 | nakhon si thammarat
# Processing Record 19 of Set 9 | tak bai
# Processing Record 20 of Set 9 | barcelos
# Processing Record 21 of Set 9 | kushiro
# Processing Record 22 of Set 9 | attawapiskat
# City not found. Skipping
# Processing Record 23 of Set 9 | khonuu
# City not found. Skipping
# Processing Record 24 of Set 9 | bac lieu
# Processing Record 25 of Set 9 | faya
# Processing Record 26 of Set 9 | tefe
# Processing Record 27 of Set 9 | solnechnyy
# Processing Record 28 of Set 9 | kununurra
# Processing Record 29 of Set 9 | colon
# Processing Record 30 of Set 9 | vung tau
# Processing Record 31 of Set 9 | bambous virieux
# Processing Record 32 of Set 9 | kita
# Processing Record 33 of Set 9 | mindelo
# Processing Record 34 of Set 9 | taitung
# Processing Record 35 of Set 9 | phan rang
# City not found. Skipping
# Processing Record 36 of Set 9 | helena
# Processing Record 37 of Set 9 | buqayq
# City not found. Skipping
# Processing Record 38 of Set 9 | durusu
# Processing Record 39 of Set 9 | ucluelet
# Processing Record 40 of Set 9 | loandjili
# Processing Record 41 of Set 9 | waingapu
# Processing Record 42 of Set 9 | ribeira grande
# Processing Record 43 of Set 9 | west bay
# Processing Record 44 of Set 9 | krasnouralsk
# Processing Record 45 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping
# Processing Record 46 of Set 9 | whitehorse
# Processing Record 47 of Set 9 | butembo
# Processing Record 48 of Set 9 | honningsvag
# Processing Record 49 of Set 9 | sobolevo
# Processing Record 50 of Set 9 | sibolga
# Processing Record 1 of Set 10 | ambilobe
# Processing Record 2 of Set 10 | cayeli
# Processing Record 3 of Set 10 | oyama
# Processing Record 4 of Set 10 | trairi
# Processing Record 5 of Set 10 | wilmington
# Processing Record 6 of Set 10 | salinas
# Processing Record 7 of Set 10 | sioux lookout
# Processing Record 8 of Set 10 | ayan
# Processing Record 9 of Set 10 | borogontsy
# Processing Record 10 of Set 10 | mecca
# Processing Record 11 of Set 10 | constantine
# Processing Record 12 of Set 10 | bismil
# Processing Record 13 of Set 10 | geresk
# City not found. Skipping
# Processing Record 14 of Set 10 | porto murtinho
# Processing Record 15 of Set 10 | palmer
# Processing Record 16 of Set 10 | mosquera
# Processing Record 17 of Set 10 | huejuquilla el alto
# Processing Record 18 of Set 10 | katherine
# Processing Record 19 of Set 10 | ponta delgada
# Processing Record 20 of Set 10 | gornopravdinsk
# Processing Record 21 of Set 10 | goure
# Processing Record 22 of Set 10 | lolua
# City not found. Skipping
# Processing Record 23 of Set 10 | nguiu
# City not found. Skipping
# Processing Record 24 of Set 10 | jiddah
# City not found. Skipping
# Processing Record 25 of Set 10 | honiara
# Processing Record 26 of Set 10 | aswan
# Processing Record 27 of Set 10 | omsukchan
# Processing Record 28 of Set 10 | loreto
# Processing Record 29 of Set 10 | nong khai
# Processing Record 30 of Set 10 | zhanatas
# City not found. Skipping
# Processing Record 31 of Set 10 | kracheh
# City not found. Skipping
# Processing Record 32 of Set 10 | virginia beach
# Processing Record 33 of Set 10 | gamba
# Processing Record 34 of Set 10 | banda aceh
# Processing Record 35 of Set 10 | neiafu
# Processing Record 36 of Set 10 | bedesa
# Processing Record 37 of Set 10 | sorland
# Processing Record 38 of Set 10 | quatre cocos
# Processing Record 39 of Set 10 | coari
# Processing Record 40 of Set 10 | saryozek
# Processing Record 41 of Set 10 | luau
# Processing Record 42 of Set 10 | san borja
# Processing Record 43 of Set 10 | fort-shevchenko
# Processing Record 44 of Set 10 | palitana
# Processing Record 45 of Set 10 | palabuhanratu
# City not found. Skipping
# Processing Record 46 of Set 10 | kondinskoye
# Processing Record 47 of Set 10 | araouane
# Processing Record 48 of Set 10 | borger
# Processing Record 49 of Set 10 | troy
# Processing Record 50 of Set 10 | burkhala
# City not found. Skipping
# Processing Record 1 of Set 11 | jalu
# Processing Record 2 of Set 11 | yagoua
# Processing Record 3 of Set 11 | naze
# Processing Record 4 of Set 11 | kindu
# Processing Record 5 of Set 11 | tual
# Processing Record 6 of Set 11 | haines junction
# Processing Record 7 of Set 11 | salou
# Processing Record 8 of Set 11 | puerto leguizamo
# Processing Record 9 of Set 11 | rocha
# Processing Record 10 of Set 11 | altamira
# Processing Record 11 of Set 11 | matara
# Processing Record 12 of Set 11 | ouallam
# Processing Record 13 of Set 11 | jijiga
# Processing Record 14 of Set 11 | simpang
# Processing Record 15 of Set 11 | tuy hoa
# Processing Record 16 of Set 11 | mersing
# Processing Record 17 of Set 11 | pokaran
# Processing Record 18 of Set 11 | alofi
# Processing Record 19 of Set 11 | ilhabela
# Processing Record 20 of Set 11 | harnosand
# Processing Record 21 of Set 11 | dali
# Processing Record 22 of Set 11 | koboko
# Processing Record 23 of Set 11 | richards bay
# Processing Record 24 of Set 11 | ocos
# Processing Record 25 of Set 11 | tumannyy
# City not found. Skipping
# Processing Record 26 of Set 11 | hun
# Processing Record 27 of Set 11 | belaya gora
# Processing Record 28 of Set 11 | copiapo
# Processing Record 29 of Set 11 | cayhagan
# Processing Record 30 of Set 11 | fort saint john
# City not found. Skipping
# Processing Record 31 of Set 11 | hayden
# Processing Record 32 of Set 11 | kaspiyskiy
# Processing Record 33 of Set 11 | milingimbi
# City not found. Skipping
# Processing Record 34 of Set 11 | kimbe
# Processing Record 35 of Set 11 | aquiraz
# Processing Record 36 of Set 11 | diu
# Processing Record 37 of Set 11 | manicore
# Processing Record 38 of Set 11 | norsup
# Processing Record 39 of Set 11 | luena
# Processing Record 40 of Set 11 | okhtyrka
# Processing Record 41 of Set 11 | jining
# Processing Record 42 of Set 11 | ijaki
# City not found. Skipping
# Processing Record 43 of Set 11 | chavakkad
# Processing Record 44 of Set 11 | vigia del fuerte
# Processing Record 45 of Set 11 | yudong
# Processing Record 46 of Set 11 | saint-augustin
# Processing Record 47 of Set 11 | sola
# Processing Record 48 of Set 11 | salalah
# Processing Record 49 of Set 11 | volkhov
# Processing Record 50 of Set 11 | belen
# Processing Record 1 of Set 12 | gurgan
# City not found. Skipping
# Processing Record 2 of Set 12 | uzhur-4
# City not found. Skipping
# Processing Record 3 of Set 12 | acapulco
# Processing Record 4 of Set 12 | bandarbeyla
# Processing Record 5 of Set 12 | chagda
# City not found. Skipping
# Processing Record 6 of Set 12 | northam
# Processing Record 7 of Set 12 | santiago del estero
# Processing Record 8 of Set 12 | muros
# Processing Record 9 of Set 12 | nacala
# Processing Record 10 of Set 12 | lokosovo
# Processing Record 11 of Set 12 | maniitsoq
# Processing Record 12 of Set 12 | scottsbluff
# Processing Record 13 of Set 12 | srandakan
# Processing Record 14 of Set 12 | broken hill
# Processing Record 15 of Set 12 | pontes e lacerda
# Processing Record 16 of Set 12 | kirakira
# Processing Record 17 of Set 12 | cap-aux-meules
# Processing Record 18 of Set 12 | vila
# Processing Record 19 of Set 12 | san carlos de bariloche
# Processing Record 20 of Set 12 | joshimath
# Processing Record 21 of Set 12 | rovaniemi
# Processing Record 22 of Set 12 | rafai
# Processing Record 23 of Set 12 | waw
# Processing Record 24 of Set 12 | great falls
# Processing Record 25 of Set 12 | larsnes
# Processing Record 26 of Set 12 | avera
# Processing Record 27 of Set 12 | san lazaro
# Processing Record 28 of Set 12 | abha
# Processing Record 29 of Set 12 | hearst
# Processing Record 30 of Set 12 | wajima
# Processing Record 31 of Set 12 | kaniama
# Processing Record 32 of Set 12 | pyay
# Processing Record 33 of Set 12 | ketchikan
# Processing Record 34 of Set 12 | horki
# Processing Record 35 of Set 12 | shouguang
# Processing Record 36 of Set 12 | sinnamary
# Processing Record 37 of Set 12 | misratah
# Processing Record 38 of Set 12 | tingo maria
# Processing Record 39 of Set 12 | flinders
# Processing Record 40 of Set 12 | ossora
# Processing Record 41 of Set 12 | marzuq
# Processing Record 42 of Set 12 | hay river
# Processing Record 43 of Set 12 | puerto pinasco
# City not found. Skipping
# Processing Record 44 of Set 12 | redmond
# Processing Record 45 of Set 12 | abu dhabi
# Processing Record 46 of Set 12 | aykhal
# Processing Record 47 of Set 12 | wexford
# Processing Record 48 of Set 12 | cheuskiny
# City not found. Skipping
# Processing Record 49 of Set 12 | road town
# Processing Record 50 of Set 12 | riyadh
# Processing Record 1 of Set 13 | barguzin
# Processing Record 2 of Set 13 | kemi
# Processing Record 3 of Set 13 | sao miguel do araguaia
# Processing Record 4 of Set 13 | oistins
# Processing Record 5 of Set 13 | saleaula
# City not found. Skipping
# Processing Record 6 of Set 13 | poum
# Processing Record 7 of Set 13 | tazmalt
# Processing Record 8 of Set 13 | manta
# Processing Record 9 of Set 13 | tema
# Processing Record 10 of Set 13 | tabou
# Processing Record 11 of Set 13 | veletma
# City not found. Skipping
# Processing Record 12 of Set 13 | mudyuga
# City not found. Skipping
# Processing Record 13 of Set 13 | tanout
# Processing Record 14 of Set 13 | brigantine
# Processing Record 15 of Set 13 | huallanca
# Processing Record 16 of Set 13 | cordoba
# Processing Record 17 of Set 13 | makakilo city
# Processing Record 18 of Set 13 | chatellerault
# Processing Record 19 of Set 13 | kenai
# Processing Record 20 of Set 13 | maebaru
# Processing Record 21 of Set 13 | benguela
# Processing Record 22 of Set 13 | yueyang
# Processing Record 23 of Set 13 | margate
# Processing Record 24 of Set 13 | camana
# Processing Record 25 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 13 | belfast
# Processing Record 27 of Set 13 | prainha
# Processing Record 28 of Set 13 | shingu
# Processing Record 29 of Set 13 | arys
# Processing Record 30 of Set 13 | blue springs
# Processing Record 31 of Set 13 | lagunas
# Processing Record 32 of Set 13 | teguldet
# Processing Record 33 of Set 13 | bonavista
# Processing Record 34 of Set 13 | marienburg
# Processing Record 35 of Set 13 | daitari
# Processing Record 36 of Set 13 | ibiapina
# Processing Record 37 of Set 13 | zhangjiakou
# Processing Record 38 of Set 13 | mishkino
# Processing Record 39 of Set 13 | matay
# Processing Record 40 of Set 13 | chapais
# Processing Record 41 of Set 13 | portland
# Processing Record 42 of Set 13 | arcata
# Processing Record 43 of Set 13 | yeppoon
# Processing Record 44 of Set 13 | vila franca do campo
# Processing Record 45 of Set 13 | san pedro de uraba
# Processing Record 46 of Set 13 | puerto madryn
# Processing Record 47 of Set 13 | ghanzi
# Processing Record 48 of Set 13 | dahuk
# Processing Record 49 of Set 13 | almas
# Processing Record 50 of Set 13 | christchurch
# Processing Record 1 of Set 14 | zherdevka
# Processing Record 2 of Set 14 | susanville
# Processing Record 3 of Set 14 | camalu
# Processing Record 4 of Set 14 | vila velha
# Processing Record 5 of Set 14 | nome
# Processing Record 6 of Set 14 | aklavik
# Processing Record 7 of Set 14 | kano
# Processing Record 8 of Set 14 | polovinnoye
# Processing Record 9 of Set 14 | suntar
# Processing Record 10 of Set 14 | spirovo
# Processing Record 11 of Set 14 | mangrol
# Processing Record 12 of Set 14 | hirado
# Processing Record 13 of Set 14 | fairbanks
# Processing Record 14 of Set 14 | lagoa
# Processing Record 15 of Set 14 | mugur-aksy
# Processing Record 16 of Set 14 | hualmay
# Processing Record 17 of Set 14 | sao joao da barra
# Processing Record 18 of Set 14 | asha
# Processing Record 19 of Set 14 | sarkand
# Processing Record 20 of Set 14 | noumea
# Processing Record 21 of Set 14 | ituni
# City not found. Skipping
# Processing Record 22 of Set 14 | kenitra
# Processing Record 23 of Set 14 | gazimagusa
# City not found. Skipping
# Processing Record 24 of Set 14 | auki
# Processing Record 25 of Set 14 | fenyi
# Processing Record 26 of Set 14 | karratha
# Processing Record 27 of Set 14 | beringovskiy
# Processing Record 28 of Set 14 | gibara
# Processing Record 29 of Set 14 | esna
# Processing Record 30 of Set 14 | namyslow
# Processing Record 31 of Set 14 | bontang
# Processing Record 32 of Set 14 | hirara
# Processing Record 33 of Set 14 | toora-khem
# Processing Record 34 of Set 14 | burica
# City not found. Skipping
# Processing Record 35 of Set 14 | meulaboh
# Processing Record 36 of Set 14 | santiago de cuba
# Processing Record 37 of Set 14 | eydhafushi
# Processing Record 38 of Set 14 | dukat
# Processing Record 39 of Set 14 | hvittingfoss
# Processing Record 40 of Set 14 | novyy urengoy
# Processing Record 41 of Set 14 | cockburn town
# Processing Record 42 of Set 14 | chippewa falls
# Processing Record 43 of Set 14 | khani
# Processing Record 44 of Set 14 | obo
# Processing Record 45 of Set 14 | yala
# Processing Record 46 of Set 14 | ji-parana
# City not found. Skipping
# Processing Record 47 of Set 14 | paita
# Processing Record 48 of Set 14 | deputatskiy
# Processing Record 49 of Set 14 | baykit
# Processing Record 50 of Set 14 | sao jose da coroa grande
# Processing Record 1 of Set 15 | rio grande
# Processing Record 2 of Set 15 | abu zabad
# Processing Record 3 of Set 15 | arlit
# Processing Record 4 of Set 15 | opobo
# City not found. Skipping
# Processing Record 5 of Set 15 | molina
# Processing Record 6 of Set 15 | axim
# Processing Record 7 of Set 15 | pundaguitan
# Processing Record 8 of Set 15 | kokorevka
# Processing Record 9 of Set 15 | cuiluan
# Processing Record 10 of Set 15 | dwarka
# Processing Record 11 of Set 15 | weihe
# Processing Record 12 of Set 15 | bitkine
# Processing Record 13 of Set 15 | mayya
# Processing Record 14 of Set 15 | iwanai
# Processing Record 15 of Set 15 | mysliborz
# Processing Record 16 of Set 15 | jaca
# Processing Record 17 of Set 15 | staryy nadym
# Processing Record 18 of Set 15 | pampa
# Processing Record 19 of Set 15 | antsohihy
# Processing Record 20 of Set 15 | shimoda
# Processing Record 21 of Set 15 | lincoln
# Processing Record 22 of Set 15 | mkushi
# Processing Record 23 of Set 15 | buraydah
# Processing Record 24 of Set 15 | kondoa
# Processing Record 25 of Set 15 | kargasok
# Processing Record 26 of Set 15 | patnagarh
# Processing Record 27 of Set 15 | abonnema
# Processing Record 28 of Set 15 | huarmey
# Processing Record 29 of Set 15 | nizhniy odes
# Processing Record 30 of Set 15 | taoudenni
# Processing Record 31 of Set 15 | morant bay
# Processing Record 32 of Set 15 | lock haven
# Processing Record 33 of Set 15 | kiruna
# Processing Record 34 of Set 15 | pochutla
# Processing Record 35 of Set 15 | khash
# Processing Record 36 of Set 15 | dzhusaly
# City not found. Skipping
# Processing Record 37 of Set 15 | atbasar
# Processing Record 38 of Set 15 | onalaska
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 673

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0      Ostersund      SE  2022-07-25 23:57:24  63.1792   14.6357     57.65
# 1          Tiksi      RU  2022-07-25 23:57:25  71.6872  128.8694     50.99
# 2         Castro      BR  2022-07-25 23:57:26 -24.7911  -50.0119     59.70
# 3           Nuuk      GL  2022-07-25 23:57:26  64.1835  -51.7216     43.88
# 4       Cidreira      BR  2022-07-25 23:57:27 -30.1811  -50.2056     61.09
# 5  Srednekolymsk      RU  2022-07-25 23:57:28  67.4500  153.6833     60.64
# 6        Iqaluit      CA  2022-07-25 23:57:28  63.7506  -68.5145     47.93
# 7            Gat      IL  2022-07-25 23:57:29  31.6100   34.7642     78.40
# 8        Mataura      NZ  2022-07-25 23:57:29 -46.1927  168.8643     46.47
# 9     Port Hardy      CA  2022-07-25 23:57:30  50.6996 -127.4199     71.78
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0       100          20        9.22          few clouds
# 1        81          48        4.65    scattered clouds
# 2        72          94        2.13     overcast clouds
# 3        87          82        5.01       broken clouds
# 4        95          16        5.91          few clouds
# 5        37          38       12.35    scattered clouds
# 6        81          20       10.36          few clouds
# 7        71           0        1.90           clear sky
# 8        96         100       10.78     overcast clouds
# 9        68          20       12.66                 fog

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Date", "Lat",
                    "Lng", "Max Temp", "Cloudiness", "Humidity", "Wind Speed", "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0      Ostersund      SE  2022-07-25 23:57:24  63.1792   14.6357     57.65
# 1          Tiksi      RU  2022-07-25 23:57:25  71.6872  128.8694     50.99
# 2         Castro      BR  2022-07-25 23:57:26 -24.7911  -50.0119     59.70
# 3           Nuuk      GL  2022-07-25 23:57:26  64.1835  -51.7216     43.88
# 4       Cidreira      BR  2022-07-25 23:57:27 -30.1811  -50.2056     61.09
# 5  Srednekolymsk      RU  2022-07-25 23:57:28  67.4500  153.6833     60.64
# 6        Iqaluit      CA  2022-07-25 23:57:28  63.7506  -68.5145     47.93
# 7            Gat      IL  2022-07-25 23:57:29  31.6100   34.7642     78.40
# 8        Mataura      NZ  2022-07-25 23:57:29 -46.1927  168.8643     46.47
# 9     Port Hardy      CA  2022-07-25 23:57:30  50.6996 -127.4199     71.78
#
#    Cloudiness  Humidity  Wind Speed Current Description
# 0          20       100        9.22          few clouds
# 1          48        81        4.65    scattered clouds
# 2          94        72        2.13     overcast clouds
# 3          82        87        5.01       broken clouds
# 4          16        95        5.91          few clouds
# 5          38        37       12.35    scattered clouds
# 6          20        81       10.36          few clouds
# 7           0        71        1.90           clear sky
# 8         100        96       10.78     overcast clouds
# 9          20        68       12.66                 fog

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_df.count()
# Out:
# City                   673
# Country                673
# Date                   673
# Lat                    673
# Lng                    673
# Max Temp               673
# Cloudiness             673
# Humidity               673
# Wind Speed             673
# Current Description    673
# dtype: int64
